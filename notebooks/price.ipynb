# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN, KMeans
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('../barca.csv', header=0)
df.head()
# Out:
#      room_type    neighborhood  reviews  overall_satisfaction  accommodates  \
# 0  Shared room        Eixample       27                   4.5            10
# 1  Shared room  Sants-Montjuïc       13                   4.0            12
# 2  Shared room  Sants-Montjuïc       11                   4.0            12
# 3  Shared room        Eixample        9                   5.0             2
# 4  Shared room        Eixample       10                   5.0             2
#
#    bedrooms  price   latitude  longitude
# 0       1.0  264.0  41.391617   2.162516
# 1       1.0  129.0  41.373268   2.170138
# 2       1.0  129.0  41.372360   2.169215
# 3       1.0   72.0  41.391836   2.154014
# 4       1.0   64.0  41.387623   2.148761

# %%
os = df['overall_satisfaction'].value_counts()
fig = os.plot.bar()
fig.get_figure().savefig('distribution')

# %%
coords = df[['latitude', 'longitude']]
nbrs = KMeans(n_clusters=10).fit_predict(coords)

# %%
plt.scatter('latitude', 'longitude', data=coords, c=nbrs, alpha=0.5, s=3)

# %%
ax = df.plot(x='price', y='overall_satisfaction', kind='scatter', alpha=0.4)
ax

# %%
ax = plt.scatter(x=nbrs, y=df['overall_satisfaction'])

# %%
ds = pd.cut(df['price'], 15, labels=False)
ax = plt.scatter(x=ds, y=df['overall_satisfaction'], alpha=0.4)
ax.set_xlabel('price')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-6177fb865180> in <module>
#       1 ds = pd.cut(df['price'], 15, labels=False)
#       2 ax = plt.scatter(x=ds, y=df['overall_satisfaction'], alpha=0.4)
# ----> 3 ax.set_xlabel('price')
#
# AttributeError: 'PathCollection' object has no attribute 'set_xlabel'

# %%
ax.get_figure().savefig('price-cut.png')

# %%
ax = df.plot(x='reviews', y='overall_satisfaction', kind='scatter', alpha=0.4)

# %%
ds = pd.cut(df['reviews'], 10, labels=False)
ax = plt.scatter(x=ds, y=df['overall_satisfaction'], alpha=0.4)
ax.get_figure().savefig('reviews-cut.png')

# %%
ax = df.plot(x='latitude', y='overall_satisfaction', kind='scatter', alpha=0.2)

# %%
ds = pd.cut(df['latitude'], 20, labels=False)
ax = plt.scatter(x=ds, y=df['overall_satisfaction'], alpha=0.4)
ax.get_figure().savefig('latitude-cut.png')

# %%
ax = df.plot(x='longitude', y='overall_satisfaction', kind='scatter', alpha=0.4)

# %%
ds = pd.cut(df['longitude'], 20, labels=False)
ax = plt.scatter(x=ds, y=df['overall_satisfaction'], alpha=0.4)
ax.get_figure().savefig('longitude-cut.png')

# %%
df.plot(x='')

# %%
fig, ax = plt.subplots()
ax.plot(p[0])
